# %%
import numpy as np  
#import pandas as pd
import matplotlib.pyplot as plt
import PIL
import PIL.Image
import glob
import cv2
import os
import seaborn as sns
import tensorflow as tf
import keras
import xgboost as xgb
import pickle
#import shutil

from keras.models import Model, Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.applications.vgg16 import VGG16

from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.5
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
# Read input images and assign labels based on folder names
print(os.listdir("C:\\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/"))

SIZE = 256  #Resize images

#Capture training data and labels into respective lists
train_images = []
train_labels = [] 

for directory_path in glob.glob("C:\\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train/*"):
    label = directory_path.split("\\")[-1]
    print(label)
    for img_path in glob.glob(os.path.join(directory_path, "*.jpg")):
        print(img_path)
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE, SIZE))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        train_images.append(img)
        train_labels.append(label)
        
#Convert lists to arrays        
train_images = np.array(train_images)
train_labels = np.array(train_labels)
# Out:
# ['test', 'train', 'val']
# black_pod_rot
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_1.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_10.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_100.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_103.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_11.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_12.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_13.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_14.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_15.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_17.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_2.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_20.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_22.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_23.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_24.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_25.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_26.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_27.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_28.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_29.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_3.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_33.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_35.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_36.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_37.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_39.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_4.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_40.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_41.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_42.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_43.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_44.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_45.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_46.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_47.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_48.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_49.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_5.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_50.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_51.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_52.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_53.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_54.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_56.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_57.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_58.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_59.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_6.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_60.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_61.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_62.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_63.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_65.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_66.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_67.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_68.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_7.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_70.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_71.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_72.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_73.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_75.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_76.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_77.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_78.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_79.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_80.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_81.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_82.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_83.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_85.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_86.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_87.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_89.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_9.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_90.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_92.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_93.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_94.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_95.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_98.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\black_pod_rot\black_pod_rot_99.jpg
# healthy
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_1.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_10.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_100.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_103.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_11.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_12.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_13.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_14.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_15.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_17.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_2.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_20.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_22.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_23.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_24.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_25.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_26.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_27.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_28.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_29.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_3.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_33.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_35.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_36.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_37.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_39.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_4.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_40.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_41.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_42.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_43.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_44.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_45.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_46.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_47.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_48.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_49.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_5.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_50.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_51.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_52.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_53.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_54.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_56.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_57.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_58.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_59.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_6.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_60.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_61.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_62.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_63.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_65.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_66.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_67.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_68.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_7.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_70.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_71.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_72.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_73.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_75.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_76.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_77.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_78.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_79.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_80.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_81.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_82.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_83.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_85.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_86.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_87.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_89.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_9.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_90.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_92.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_93.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_94.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_95.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_98.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\healthy\healthy_99.jpg
# pod_borer
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_1.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_10.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_100.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_103.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_11.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_12.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_13.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_14.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_15.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_17.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_2.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_20.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_22.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_23.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_24.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_25.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_26.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_27.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_28.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_29.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_3.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_33.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_35.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_36.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_37.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_39.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_4.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_40.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_41.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_42.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_43.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_44.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_45.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_46.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_47.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_48.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_49.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_5.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_50.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_51.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_52.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_53.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_54.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_56.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_57.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_58.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_59.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_6.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_60.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_61.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_62.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_63.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_65.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_66.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_67.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_68.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_7.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_70.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_71.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_72.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_73.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_75.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_76.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_77.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_78.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_79.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_80.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_81.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_82.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_83.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_85.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_86.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_87.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_89.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_9.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_90.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_92.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_93.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_94.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_95.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_98.jpg
# C:\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/train\pod_borer\pod_borer_99.jpg

# %%
# Capture test/validation data and labels into respective lists

test_images = []
test_labels = [] 
for directory_path in glob.glob("C:\\Users\Administrator\Desktop\Cacao V4 model\Cacao V4 dataset/val/*"):
    fruit_label = directory_path.split("\\")[-1]
    for img_path in glob.glob(os.path.join(directory_path, "*.jpg")):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        img = cv2.resize(img, (SIZE, SIZE))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        test_images.append(img)
        test_labels.append(fruit_label)

#Convert lists to arrays                
test_images = np.array(test_images)
test_labels = np.array(test_labels)

# %%
#Encode labels from text to integers.
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(test_labels)
test_labels_encoded = le.transform(test_labels)
le.fit(train_labels)
train_labels_encoded = le.transform(train_labels)

# %%
#Split data into test and train datasets (already split but assigning to meaningful convention)
x_train, y_train, x_test, y_test = train_images, train_labels_encoded, test_images, test_labels_encoded

# %%
# Normalize pixel values to between 0 and 1
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
#Load model wothout classifier/fully connected layers
VGG_model = VGG16(weights='imagenet', include_top=False, input_shape=(SIZE, SIZE, 3))

# %%
#Make loaded layers as non-trainable. This is important as we want to work with pre-trained weights
for layer in VGG_model.layers:
	layer.trainable = False
    
VGG_model.summary()  #Trainable parameters will be 0
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 256, 256, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 256, 256, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 128, 128, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 128, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 128, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 64, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 64, 64, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 32, 32, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 32, 32, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
#Now, let us use features from convolutional network for RF
feature_extractor=VGG_model.predict(x_train)

# %%
features = feature_extractor.reshape(feature_extractor.shape[0], -1)

X_for_training = features #This is our X input to RF

# %%
#XGBOOST
model = xgb.XGBClassifier(eval_metric='mlogloss')
model.fit(X_for_training, y_train) #For sklearn no one hot encoding
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               eval_metric='mlogloss', gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=4,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#               subsample=1, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %%
#Send test data through same feature extractor process
X_test_feature = VGG_model.predict(x_test)
X_test_features = X_test_feature.reshape(X_test_feature.shape[0], -1)

# %%
#Now predict using the trained RF model. 
prediction = model.predict(X_test_features)
#Inverse le transform to get original label back. 
prediction = le.inverse_transform(prediction)

# %%
#Print overall accuracy
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, prediction))
# Out:
# Accuracy =  0.7333333333333333

# %%
#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, prediction)
#print(cm)
sns.heatmap(cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
#Check results on a test images
n=np.random.randint(0, x_test.shape[0])
img = x_test[n]
plt.imshow(img)

input_img = np.expand_dims(img, axis=0) #Expand dims so the input is (num images, x, y, c)
input_img_feature=VGG_model.predict(input_img)

input_img_features=input_img_feature.reshape(input_img_feature.shape[0], -1)

prediction = model.predict(input_img_features)[0] 

prediction = le.inverse_transform([prediction])  #Reverse the label encoder to original name

print("The prediction for this image is: ", prediction)

print("The actual label for this image is: ", test_labels[n])
# Out:
# The prediction for this image is:  ['pod_borer']
# The actual label for this image is:  healthy

# %%
with open('V3_model','wb') as f :
    pickle.dump(model,f)

# %%
pickle.dump(model, open("model.sav", "wb"))

# %%
model_pred = pickle.load(open("model.sav", "rb"))

#img = img.open()
#plt.imshow(img)
#preds = model_pred.predict(X_test_scaled)

from PIL import Image


img = "C:\\Users\Administrator\Desktop\Cacao V3 model training\pod_borer_4.jpg"
img = Image.open(img)
plt.imshow(img)

img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
img = cv2.resize(img, (SIZE, SIZE))
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
#img = np.array(img)
input_img = np.expand_dims(img, axis=0)
input_img = input_img.reshape(255, 255)
input_img_feature=VGG_model.predict(input_img)
prediction = model_pred.predict(img)

print("The prediction for this image is: ", prediction)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-6ef09fd54d8c> in <module>
#      17 #img = np.array(img)
#      18 input_img = np.expand_dims(img, axis=0)
# ---> 19 input_img = input_img.resize(255, 255)
#      20 input_img_feature=VGG_model.predict(input_img)
#      21 prediction = model_pred.predict(img)
#
# ValueError: cannot resize this array: it does not own its data
